# %% [markdown]
# # Evaluation du coût d'un trajet
#
# Dans ce notebook, nous estimons les paramètres du coût d'un trajet. Pour cela, nous utilusons les données récoltées dans notre formulaire: le point de départ, le point d'arrivée, la tranche horaire du déplacement ainsi que el coût

# %% [markdown]
# > [!IMPORTANT]
# > Avant d'exécuter les cellules suivantges, vous devez d'abord installer les dépendances du projet avec la commande `pip install requirements.txt`

# %% [markdown]
# ## Chargement et exploration du dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('Collecte de données de transport dans la ville de Yaoundé..csv')
df
# Out:
#                       Horodateur Précisez le coût du trajet en FCFA  \
# 0    2024/12/01 5:40:22 PM UTC+1                                NaN
# 1    2024/12/01 5:41:03 PM UTC+1                                NaN
# 2    2024/12/01 5:44:32 PM UTC+1                                500
# 3    2024/12/01 5:45:00 PM UTC+1                                400
# 4    2024/12/01 5:46:24 PM UTC+1                                500
# 5    2024/12/01 5:51:29 PM UTC+1                            500fcfa
# 6    2024/12/01 6:02:13 PM UTC+1                                350
# 7    2024/12/01 6:11:28 PM UTC+1                                400
# 8    2024/12/01 6:14:35 PM UTC+1                               600
# 9    2024/12/01 6:15:03 PM UTC+1                                350
# 10   2024/12/01 6:15:44 PM UTC+1                                400
# 11   2024/12/01 6:16:17 PM UTC+1                                400
# 12   2024/12/01 6:16:50 PM UTC+1                                200
# 13   2024/12/01 6:17:18 PM UTC+1                                400
# 14   2024/12/01 6:17:59 PM UTC+1                                350
# 15   2024/12/01 6:39:11 PM UTC+1                                150
# 16   2024/12/01 6:47:27 PM UTC+1                                400
# 17   2024/12/01 6:49:06 PM UTC+1                                500
# 18   2024/12/01 6:50:36 PM UTC+1                                300
# 19   2024/12/01 6:51:08 PM UTC+1                                400
# 20   2024/12/01 6:51:41 PM UTC+1                                300
# 21   2024/12/01 6:52:28 PM UTC+1                                150
# 22   2024/12/01 6:52:51 PM UTC+1                                300
# 23   2024/12/01 6:53:44 PM UTC+1                                150
# 24   2024/12/01 6:54:08 PM UTC+1                                500
# 25   2024/12/01 6:55:25 PM UTC+1                                200
# 26   2024/12/01 6:56:22 PM UTC+1                                500
# 27   2024/12/01 6:57:52 PM UTC+1                                300
# 28   2024/12/01 6:59:25 PM UTC+1                                100
# 29   2024/12/01 7:00:16 PM UTC+1                                100
# 30   2024/12/01 7:01:34 PM UTC+1                                300
# 31   2024/12/01 7:08:03 PM UTC+1                                300
# 32   2024/12/01 7:13:00 PM UTC+1                          D’accord
# 33   2024/12/01 9:34:22 PM UTC+1                                500
# 34   2024/12/01 9:50:56 PM UTC+1                                600
# 35   2024/12/02 7:06:35 AM UTC+1                                350
# 36   2024/12/02 7:07:49 AM UTC+1                                350
# 37  2024/12/02 10:05:31 AM UTC+1                                350
# 38   2024/12/03 9:51:03 AM UTC+1                                500
# 39  2024/12/03 10:02:03 AM UTC+1                                350
# 40  2024/12/03 10:22:04 AM UTC+1                               1200
# 41  2024/12/03 12:34:31 PM UTC+1                                500
# 42   2024/12/03 8:01:14 PM UTC+1                                700
#
#    Rappelez-vous d'un trajet que vous avez eu à faire dans la ville de Yaoundé via un taxi 🚕 🚖.\n\nIndiquez le lieu de départ du trajet:  \
# 0                                      Polytechnique
# 1                                                Mvan
# 2                                                Mvan
# 3                                               Melen
# 4                                    Carrefour Scalom
# 5                                               Melen
# 6                                             Mendong
# 7                                           Jouvence
# 8                                            Simbock
# 9                                              Cite u
# 10                                           Simbock
# 11                                             Cite u
# 12                                            Cite u
# 13                                            Cité u
# 14                                         Omnisport
# 15                                           chez moi
# 16                                              Melen
# 17                                              Melen
# 18                                              Melen
# 19                                           Ekounou
# 20                                            Ekounou
# 21                                              Melen
# 22                                              Melen
# 23                               Entrée complexe beac
# 24                                              Melen
# 25                                         Mvog Betsi
# 26                                     Polytechnique
# 27                             Polytechnique Yaoundé
# 28                                              Melen
# 29                                     Carrefour MEEC
# 30                                              Melen
# 31                                       NGOA EKELLE
# 32                                               EMIA
# 33                                               Emia
# 34                                           Simbock
# 35                                       Mobile Essos
# 36                                          Polytech
# 37                                    Entrée Simbock
# 38                                       Tradex Emana
# 39                                                CHU
# 40                                              poste
# 41                                             Cradat
# 42                                           Fougerol
#
#                             Indiquez la destination :  \
# 0                                           Jouvence
# 1                                               Melen
# 2                                               Melen
# 3                                                Mvan
# 4                                  Carrefour nkoabang
# 5                                           Nkoabang
# 6                                                 CHU
# 7                                               Melen
# 8                                              Melen
# 9                                            Simbock
# 10                                            Cite u
# 11                                           Simbock
# 12                                     Polytechnique
# 13                                         Omnisport
# 14                                             Cité u
# 15                                            l'ecole
# 16                                    Hôpital General
# 17                                   Hôpital General
# 18                                            Ekounou
# 19                                              Melen
# 20                                             Melen
# 21                                    Poste centrale
# 22                                              Warda
# 23                               Carrefour Mbog Abang
# 24                                           Ekounou
# 25                             Polytechnique Yaoundé
# 26                                               Odza
# 27                                        Mvog Betsi
# 28                                     Carrefour MEEC
# 29                                              Melen
# 30                                    Poste Centrale
# 31                             Polytechnique Yaoundé
# 32                                          Nkometou
# 33                                             Nkozoa
# 34                                              Melen
# 35                                          Polytech
# 36                                       Mobile Essos
# 37  École Nationale Supérieure Polytechnique de Ya...
# 38                                  Polytech Yaoundé
# 39                                           Nkoabang
# 40                                               odza
# 41                                  Carrefour Essomba
# 42                                     Pharmacie Emia
#
#    Précisez la tranche horaire de l'heure de départ:
# 0                                      15h30 - 18h59
# 1                                      05h00 - 06h59
# 2                                      07h00 - 08h59
# 3                                      09h00 - 13h59
# 4                                      09h00 - 13h59
# 5                                      15h30 - 18h59
# 6                                      07h00 - 08h59
# 7                                      07h00 - 08h59
# 8                                      07h00 - 08h59
# 9                                      14h00 - 15h29
# 10                                     21h01 - 23h59
# 11                                     19h00 - 21h00
# 12                                     07h00 - 08h59
# 13                                     19h00 - 21h00
# 14                                     21h01 - 23h59
# 15                                     07h00 - 08h59
# 16                                     14h00 - 15h29
# 17                                     15h30 - 18h59
# 18                                     14h00 - 15h29
# 19                                     19h00 - 21h00
# 20                                     09h00 - 13h59
# 21                                     14h00 - 15h29
# 22                                     09h00 - 13h59
# 23                                     09h00 - 13h59
# 24                                     19h00 - 21h00
# 25                                     07h00 - 08h59
# 26                                     19h00 - 21h00
# 27                                     07h00 - 08h59
# 28                                     07h00 - 08h59
# 29                                     07h00 - 08h59
# 30                                     19h00 - 21h00
# 31                                     07h00 - 08h59
# 32                                     15h30 - 18h59
# 33                                     09h00 - 13h59
# 34                                     05h00 - 06h59
# 35                                     05h00 - 06h59
# 36                                     19h00 - 21h00
# 37                                     07h00 - 08h59
# 38                                     05h00 - 06h59
# 39                                     14h00 - 15h29
# 40                                     14h00 - 15h29
# 41                                     15h30 - 18h59
# 42                                     05h00 - 06h59

# %% [markdown]
# Le dataset contient d'abord des oms de colonnes assez long, ce qui est norml vu que Google pour passer de forms à Sheets attribue les noms de questions aux colonnes.
# Nous allons d'abord les renommer. Ensuite, Google Sheets ajoute aussi la colonne Horodateur qui indique l'heure à laquelle le formulaire a été  rempli, ce qui ne nous aide pas du tout dans notre étude, nous la supprimons donc.

# %%
# Renommer les colonnes
df = df.rename(columns={
    "Précisez le coût du trajet en FCFA": "cost",
    "Rappelez-vous d'un trajet que vous avez eu à faire dans la ville de Yaoundé via un taxi 🚕 🚖.\n\nIndiquez le lieu de départ du trajet:": "start",
    "Indiquez la destination :": "end",
    "Précisez la tranche horaire de l'heure de départ:": "hour"
})

# Supprimer la colonne "Horodateur"
df = df.drop(columns=["Horodateur"])

df.head(5)
# Out:
#   cost             start                 end           hour
# 0  NaN    Polytechnique            Jouvence   15h30 - 18h59
# 1  NaN              Mvan               Melen  05h00 - 06h59
# 2  500              Mvan               Melen  07h00 - 08h59
# 3  400             Melen                Mvan  09h00 - 13h59
# 4  500  Carrefour Scalom  Carrefour nkoabang  09h00 - 13h59

# %% [markdown]
# Le dataset est un peu plus clair, mais il reste néanmoins mal formaté car les données actuelles sont mal formatées, donc sont inexploitables.
# Nous allons donc:
# - Supprimer les entrées contenant NaN dans le dataset
# - Formater le coût (500frs => 500)
# - Mapper chaque tranche horaire à un nombre entier de 1 à 8

# %%
# Supprimer les entrées avec un coût NaN ou contenant uniquement des chaînes sans chiffres
df = df.dropna(subset=["cost"])  # Supprimer les lignes avec NaN dans la colonne "cost"
df = df[df["cost"].str.contains(r'\d', na=False)]  # Conserver uniquement les lignes contenant des chiffres

# Extraire la partie numérique du coût
df["cost"] = df["cost"].str.extract(r'(\d+)', expand=False).astype(int)

df.head(5)
# Out:
#    cost             start                 end           hour
# 2   500              Mvan               Melen  07h00 - 08h59
# 3   400             Melen                Mvan  09h00 - 13h59
# 4   500  Carrefour Scalom  Carrefour nkoabang  09h00 - 13h59
# 5   500             Melen           Nkoabang   15h30 - 18h59
# 6   350           Mendong                 CHU  07h00 - 08h59

# %%
# Dictionnaire de mappage des plages horaires aux entiers
hour_mapping = {
    "Minuit - 04h59": 1,
    "05h00 - 06h59": 2,
    "07h00 - 08h59": 3,
    "09h00 - 13h59": 4,
    "14h00 - 15h29": 5,
    "15h30 - 18h59": 6,
    "19h00 - 21h00": 7,
    "21h01 - 23h59": 8
}

# Remplacer les plages horaires par les entiers
df["hour"] = df["hour"].map(hour_mapping).astype(int)

df.head(5)
# Out:
#    cost             start                 end  hour
# 2   500              Mvan               Melen     3
# 3   400             Melen                Mvan     4
# 4   500  Carrefour Scalom  Carrefour nkoabang     4
# 5   500             Melen           Nkoabang      6
# 6   350           Mendong                 CHU     3

# %% [markdown]
# ## Numérisation des données de géolocalisation
#
# Cette partie est très cruciale pour notre travail, car il s'agit ici de changer les valeurs des points de départ et d'arrivée en latitudes et longitudes.

# %%
import requests # Pour requêter une API
from geopy.distance import geodesic

# %%
# Fonction pour obtenir les coordonnées à partir d'un quartier
def get_coordinates(neighborhood, city="Yaoundé", country="Cameroon"):
    address = f"{neighborhood}, {city}, {country}"
    url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": address,
        "format": "json",
        "limit": 1
    }
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    response = requests.get(url, params=params, headers=headers)
    if response.status_code == 200 and response.json():
        data = response.json()[0]
        return float(data["lon"]), float(data["lat"])  # Renvoie (longitude, latitude)
    else:
        return None, None

# %% [markdown]
# La fonction que ous avons défini nous permet de passer d'un point écrit comme une String à sson couple de coordonnées géographiques eb utilisant l'API d'OpenStreetMap
#
# Nous allons donc initier un nouveau dataframe `data` qui contiendra nos données numériques

# %%
data = df.copy()

# Initialiser les nouvelles colonnes
data["start_long"] = None
data["start_lat"] = None
data["end_long"] = None
data["end_lat"] = None
data["distance"] = None

# Parcourir chaque ligne pour effectuer les transformations
for index, row in data.iterrows():
    # Obtenir les coordonnées du lieu de départ
    start_long, start_lat = get_coordinates(row["start"])
    # Obtenir les coordonnées du lieu de destination
    end_long, end_lat = get_coordinates(row["end"])
    
    # Mettre à jour les colonnes de coordonnées
    data.at[index, "start_long"] = start_long
    data.at[index, "start_lat"] = start_lat
    data.at[index, "end_long"] = end_long
    data.at[index, "end_lat"] = end_lat
    
    # Calculer la distance si les coordonnées sont disponibles
    if start_lat and start_long and end_lat and end_long:
        start_coords = (start_lat, start_long)
        end_coords = (end_lat, end_long)
        data.at[index, "distance"] = geodesic(start_coords, end_coords).kilometers

# Garder uniquement les colonnes nécessaires
data = data[["start_long", "start_lat", "end_long", "end_lat", "distance", "cost", "hour"]]

data.head(5)
# Out:
#   start_long start_lat   end_long   end_lat  distance  cost  hour
# 2  11.516337  3.822583  11.496399  3.864589  5.145869   500     3
# 3  11.496399  3.864589  11.516337  3.822583  5.145869   400     4
# 4       None      None       None      None      None   500     4
# 5  11.496399  3.864589       None      None      None   500     6
# 6  11.472698  3.834643  11.496076   3.86275  4.049872   350     3

# %%
data
# Out:
#    start_long start_lat   end_long   end_lat  distance  cost           hour
# 2   11.516337  3.822583  11.496399  3.864589  5.145869   500  07h00 - 08h59
# 3   11.496399  3.864589  11.516337  3.822583  5.145869   400  09h00 - 13h59
# 4        None      None       None      None      None   500  09h00 - 13h59
# 5   11.496399  3.864589       None      None      None   500  15h30 - 18h59
# 6   11.472698  3.834643  11.496076   3.86275  4.049872   350  07h00 - 08h59
# 7   11.482033  3.830017  11.496399  3.864589  4.142619   400  07h00 - 08h59
# 8   11.476172  3.809866  11.496399  3.864589  6.454839   600  07h00 - 08h59
# 9        None      None  11.476172  3.809866      None   350  14h00 - 15h29
# 10  11.476172  3.809866       None      None      None   400  21h01 - 23h59
# 11       None      None  11.476172  3.809866      None   400  19h00 - 21h00
# 12       None      None  11.500237  3.862415      None   200  07h00 - 08h59
# 13       None      None  11.540589  3.950878      None   400  19h00 - 21h00
# 14  11.540589  3.950878       None      None      None   350  21h01 - 23h59
# 15  11.517018  3.867188       None      None      None   150  07h00 - 08h59
# 16  11.496399  3.864589  11.541007  3.906918  6.815796   400  14h00 - 15h29
# 17  11.496399  3.864589  11.541007  3.906918  6.815796   500  15h30 - 18h59
# 18  11.496399  3.864589   11.53409  3.841615  4.896768   300  14h00 - 15h29
# 19   11.53409  3.841615  11.496399  3.864589  4.896768   400  19h00 - 21h00
# 20   11.53409  3.841615  11.496399  3.864589  4.896768   300  09h00 - 13h59
# 21  11.496399  3.864589  11.520538  3.860701  2.715349   150  14h00 - 15h29
# 22  11.496399  3.864589  11.512015  3.874224  2.035417   300  09h00 - 13h59
# 23       None      None       None      None      None   150  09h00 - 13h59
# 24  11.496399  3.864589   11.53409  3.841615  4.896768   500  19h00 - 21h00
# 25   11.47826  3.862809  11.500237  3.862415  2.441279   200  07h00 - 08h59
# 26  11.500237  3.862415  11.529119  3.798597  7.751902   500  19h00 - 21h00
# 27  11.500237  3.862415   11.47826  3.862809  2.441279   300  07h00 - 08h59
# 28  11.496399  3.864589  11.485067   3.86957  1.373944   100  07h00 - 08h59
# 29  11.485067   3.86957  11.496399  3.864589  1.373944   100  07h00 - 08h59
# 30  11.496399  3.864589  11.520538  3.860701  2.715349   300  19h00 - 21h00
# 31  11.505963  3.858745  11.500237  3.862415  0.754431   300  07h00 - 08h59
# 33  11.504962  3.862712  11.545125   3.93979  9.619897   500  09h00 - 13h59
# 34  11.476172  3.809866  11.496399  3.864589  6.454839   600  05h00 - 06h59
# 35  11.536035  3.872102  11.501964  3.862601  3.927277   350  05h00 - 06h59
# 36  11.501964  3.862601  11.536035  3.872102  3.927277   350  19h00 - 21h00
# 37  11.471394  3.831405  11.500237  3.862415  4.692698   350  07h00 - 08h59
# 38  11.520233  3.926415  11.501964  3.862601  7.342433   500  05h00 - 06h59
# 39  11.496076   3.86275       None      None      None   350  14h00 - 15h29
# 40       None      None  11.529119  3.798597      None  1200  14h00 - 15h29
# 41  11.499396  3.852047  11.547589  3.855302  5.364812   500  15h30 - 18h59
# 42       None      None  11.501731  3.862683      None   700  05h00 - 06h59

# %% [markdown]
# On remarque que OSM ne nous renvoie pas toutes les coordonnées de certains points. Pour l'instant, nous les supprimerons.

# %%
data_cleaned = data.dropna()
data_cleaned
# Out:
#    start_long start_lat   end_long   end_lat  distance  cost  hour
# 2   11.516337  3.822583  11.496399  3.864589  5.145869   500     3
# 3   11.496399  3.864589  11.516337  3.822583  5.145869   400     4
# 6   11.472698  3.834643  11.496076   3.86275  4.049872   350     3
# 7   11.482033  3.830017  11.496399  3.864589  4.142619   400     3
# 8   11.476172  3.809866  11.496399  3.864589  6.454839   600     3
# 16  11.496399  3.864589  11.541007  3.906918  6.815796   400     5
# 17  11.496399  3.864589  11.541007  3.906918  6.815796   500     6
# 18  11.496399  3.864589   11.53409  3.841615  4.896768   300     5
# 19   11.53409  3.841615  11.496399  3.864589  4.896768   400     7
# 20   11.53409  3.841615  11.496399  3.864589  4.896768   300     4
# 21  11.496399  3.864589  11.520538  3.860701  2.715349   150     5
# 22  11.496399  3.864589  11.512015  3.874224  2.035417   300     4
# 24  11.496399  3.864589   11.53409  3.841615  4.896768   500     7
# 25   11.47826  3.862809  11.500237  3.862415  2.441279   200     3
# 26  11.500237  3.862415  11.529119  3.798597  7.751902   500     7
# 27  11.500237  3.862415   11.47826  3.862809  2.441279   300     3
# 28  11.496399  3.864589  11.485067   3.86957  1.373944   100     3
# 29  11.485067   3.86957  11.496399  3.864589  1.373944   100     3
# 30  11.496399  3.864589  11.520538  3.860701  2.715349   300     7
# 31  11.505963  3.858745  11.500237  3.862415  0.754431   300     3
# 33  11.504962  3.862712  11.545125   3.93979  9.619897   500     4
# 34  11.476172  3.809866  11.496399  3.864589  6.454839   600     2
# 35   11.53993  3.872037  11.501964  3.862601  4.344012   350     2
# 36  11.501964  3.862601   11.53993  3.872037  4.344012   350     7
# 37  11.471394  3.831405  11.500237  3.862415  4.692698   350     3
# 38  11.520233  3.926415  11.501964  3.862601  7.342433   500     2
# 41  11.499396  3.852047  11.547589  3.855302  5.364812   500     6

# %%
lon, lat = get_coordinates('polytech')
lon
lat
# Out:
# 3.8626008

# %% [markdown]
# Nous avons ainsi un dataset numérique, prêt à être exploité.
#
# ## Visualisation des données

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for col in data_cleaned.columns:
    sns.scatterplot(x=data_cleaned['cost'], y=data[col])
    plt.xlabel('Coût du trajet')
    plt.ylabel(col)
    plt.title('Relation entre le coût et ' + col)
    plt.show()

# %%
corr = data_cleaned.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='2f')
plt.title('Matrice de corrélation')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 corr = data_cleaned.corr()
#       2 sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='2f')
#       3 plt.title('Matrice de corrélation')
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '07h00 - 08h59'

# %% [markdown]
# > [!NOTE]
# > Cette matrice montre qu'il existe une forte corrélation entre la distance et le prix du trajet

# %% [markdown]
# ## Estimation des paramètres

# %% [markdown]
# Nous commençons par séparer les features du target

# %%
X=data_cleaned[['start_long', 'start_lat', 'end_long', 'end_lat', 'distance', 'hour']]
y=data_cleaned['cost']

# %% [markdown]
# Ensuite, nous séparons les données de test et celles d'entraînement

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state=42)

# %% [markdown]
# ### Regréssion linéaire

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print(f'Erreur quadratique moyenne: {mse}')
# Out:
# Erreur quadratique moyenne: 15842.851444544931

# %%
y_pred
# Out:
# array([558.31558558, 213.702821  , 515.7037049 , 515.48395791,
#        517.07675629])

# %%
y_test
# Out:
# 19    400
# 25    200
# 20    300
# 34    600
# 2     500
# Name: cost, dtype: int64

# %% [markdown]
# ### Forêts aléatoires

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)

mse_rf = mean_squared_error(y_test, y_pred_rf)

print("Mean Squared Error (Random Forest):", mse_rf)
# Out:
# Mean Squared Error (Random Forest): 2816.0

# %%
y_pred_rf
# Out:
# array([421., 247., 386., 547., 465.])

# %% [markdown]
# ### Exemple de prédiction extra-dataset

# %%
dep = 'emia'
arr = 'polytechnique'

lon_dep, lat_dep = get_coordinates(dep)
lon_arr, lat_arr = get_coordinates(arr)
hour = 4
deps= (lon_dep, lat_dep)
arrs = (lon_arr, lat_arr)
distance = geodesic(deps, arrs).kilometers
test = [[lon_dep, lat_dep, lon_arr, lat_arr, distance, hour]]
cost = rf_model.predict(test)
cost
# Out:
# /home/folongzidane/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([260.5])
